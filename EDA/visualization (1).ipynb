# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Hari D\Downloads\New_ProjectAc.csv')
df
# Out:
#          Brand  Color  Price  no_of_star  rating  discount  Ton  \
# 0       Voltas  White  32490           3     4.2     48.00  1.5
# 1      SAMSUNG  White  30490           3     4.2     51.00  1.5
# 2        Haier  White  31990           3     4.0     50.00  1.5
# 3       Voltas  White  39490           5     4.2     48.00  1.5
# 4    Blue star  White  35900           3     4.2     42.00  1.5
# ..         ...    ...    ...         ...     ...       ...  ...
# 406    SAMSUNG  White  37388           3     4.2     18.00  1.5
# 407     Godrej  White  31900           3     3.7     30.00  1.5
# 408     Daikin  White  53000           5     4.2     15.00  1.5
# 409      Haier  White  60890           3     4.1     33.66  1.5
# 410  Panasonic  White  41350           4     4.2     30.00  1.5
#
#      annual_electricity_Consumption
# 0                            624.48
# 1                           1123.77
# 2                            686.48
# 3                            704.42
# ...

# %%
df.shape
# Out:
# (411, 8)

# %% [markdown]
# #  UNIVARIATE ANALYSIS

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### Non Visualization

# %%
df["Brand"].value_counts()
# Out:
# Daikin                45
# Voltas                43
# Lloyd                 41
# LG                    37
# SAMSUNG               31
# Hitachi               29
# Blue star             28
# Panasonic             28
# Godrej                26
# CARRIER               23
# Haier                 15
# Whirlpool              8
# IFB                    8
# MarQ                   8
# O-General              7
# ONIDA                  5
# TOSHIBA                4
# MOTOROLA               3
# realme                 3
# CANDY                  3
# Hisense                2
# CRUISE                 2
# White Westinghouse     2
# Midea                  2
# Thomson                2
# Sansui                 1
# Kelvinator             1
# Mitsubishi             1
# Frigidaire             1
# Equator                1
# NU                     1
# Name: Brand, dtype: int64

# %%
df.Brand.unique()
# Out:
# array(['Voltas', 'SAMSUNG', 'Haier', 'Blue star', 'Daikin', 'Panasonic',
#        'Whirlpool', 'Lloyd', 'Godrej', 'LG', 'CARRIER', 'ONIDA', 'IFB',
#        'MarQ', 'realme', 'Hitachi', 'Thomson', 'TOSHIBA', 'NU', 'Midea',
#        'Frigidaire', 'CANDY', 'Sansui', 'MOTOROLA', 'Kelvinator',
#        'Mitsubishi', 'CRUISE', 'O-General', 'Hisense', 'Equator',
#        'White Westinghouse'], dtype=object)

# %%
df.Brand.nunique()
# Out:
# 31

# %%
df.Color.value_counts()
# Out:
# White         399
# Gold            5
# Silver          4
# Floral          1
# Beige           1
# Multicolor      1
# Name: Color, dtype: int64

# %%
df.Color.unique()
# Out:
# array(['White', 'Gold', 'Silver', 'Floral', 'Beige', 'Multicolor'],
#       dtype=object)

# %%
df.Color.nunique()
# Out:
# 6

# %% [markdown]
# ## visualiation

# %%
df1=df[["Brand"]].head(15)
df1
# Out:
#         Brand
# 0      Voltas
# 1     SAMSUNG
# 2       Haier
# 3      Voltas
# 4   Blue star
# 5      Daikin
# 6   Panasonic
# 7   Whirlpool
# 8      Voltas
# 9     SAMSUNG
# 10     Daikin
# 11     Voltas
# 12      Lloyd
# 13     Godrej
# 14         LG

# %%
df3=df["Brand"].head(15)
df3
# Out:
# 0        Voltas
# 1       SAMSUNG
# 2         Haier
# 3        Voltas
# 4     Blue star
# 5        Daikin
# 6     Panasonic
# 7     Whirlpool
# 8        Voltas
# 9       SAMSUNG
# 10       Daikin
# 11       Voltas
# 12        Lloyd
# 13       Godrej
# 14           LG
# Name: Brand, dtype: object

# %%
colors=sns.color_palette("pastel")
df3.value_counts().plot.pie(shadow=True,autopct='%2.1f%%',labels=df3,colors=colors,radius=1)
plt.show()

# %%
df2=df.Color.tail(100)
df2
# Out:
# 311    White
# 312    White
# 313    White
# 314    White
# 315    White
#        ...
# 406    White
# 407    White
# 408    White
# 409    White
# 410    White
# Name: Color, Length: 100, dtype: object

# %%
colors=sns.color_palette("pastel")
df2.value_counts().plot.pie(shadow=True,explode=[0,0,0,0.5,0.7,0.6],radius=1,autopct='%2.1f%%',colors=colors)
plt.show()

# %%
df1.Brand.value_counts().plot.bar()
plt.show()

# %%
df.Color.value_counts().plot.bar()
plt.show()

# %% [markdown]
# # Numerical Data

# %% [markdown]
# ## Non Visualiation

# %%
df.describe()
# Out:
#               Price  no_of_star      rating    discount         Ton  \
# count    411.000000  411.000000  411.000000  411.000000  411.000000
# mean   40045.562044    3.739659    4.083455   33.861752    1.484234
# std     8910.583692    0.981715    0.376853   10.697139    0.164896
# min    19999.000000    1.000000    1.500000    1.000000    0.700000
# 25%    33994.500000    3.000000    4.000000   28.000000    1.500000
# 50%    38990.000000    3.000000    4.200000   34.000000    1.500000
# 75%    44490.000000    5.000000    4.200000   41.000000    1.500000
# max    78000.000000    5.000000    5.000000   59.000000    2.200000
#
#        annual_electricity_Consumption
# count                      411.000000
# mean                       893.018929
# std                        205.989394
# min                        577.430000
# 25%                        686.480000
# 50%                        968.610000
# 75%                       1114.710000
# max                       1134.280000

# %% [markdown]
# ## visualization

# %%
sns.boxplot(df.discount)
plt.show()

# %%
sns.boxplot(x="Price",data=df)
plt.show()

# %%
sns.boxplot(df.annual_electricity_Consumption)
# Out:
# <Axes: >

# %%
sns.histplot(x="Price",data=df,kde=True,bins=5)
plt.show()

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# ## Non Visualization

# %%
df.corr(numeric_only=True)
# Out:
#                                    Price  no_of_star    rating  discount  \
# Price                           1.000000    0.321516 -0.023804 -0.335907
# no_of_star                      0.321516    1.000000 -0.049908 -0.019684
# rating                         -0.023804   -0.049908  1.000000 -0.053905
# discount                       -0.335907   -0.019684 -0.053905  1.000000
# Ton                             0.415607    0.059408  0.005958 -0.094042
# annual_electricity_Consumption  0.003394   -0.076051 -0.058295  0.050960
#
#                                      Ton  annual_electricity_Consumption
# Price                           0.415607                        0.003394
# no_of_star                      0.059408                       -0.076051
# rating                          0.005958                       -0.058295
# discount                       -0.094042                        0.050960
# Ton                             1.000000                       -0.010936
# ...

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### NUMERICAL DATA Vs  NUMERICAL DATA

# %%
plt.scatter(df["Price"],df["discount"])
plt.title("price vs dicount")
plt.xlabel("Price")
plt.ylabel("discount")
plt.show()

# %% [markdown]
# ### CATEGORICAL DATA  Vs  NUMERICAL DATA

# %%
sns.boxplot(x=df3,y=df.rating)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### CATEGORICAL DATA  Vs  CATEGORICAL DATA

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x='Brand', y='Price', data=df, color='blue', label='Price')
sns.barplot(x='Brand', y='annual_electricity_Consumption', data=df, color='green', label='annual_electricity_Consumption')
plt.title('Average Price and annual_electricity_Consumption Capacity by Brand')
plt.xlabel('Brand')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %% [markdown]
# ## Non visualiation

# %%
df.corr(numeric_only=True)
# Out:
#                                    Price  no_of_star    rating  discount  \
# Price                           1.000000    0.321516 -0.023804 -0.335907
# no_of_star                      0.321516    1.000000 -0.049908 -0.019684
# rating                         -0.023804   -0.049908  1.000000 -0.053905
# discount                       -0.335907   -0.019684 -0.053905  1.000000
# Ton                             0.415607    0.059408  0.005958 -0.094042
# annual_electricity_Consumption  0.003394   -0.076051 -0.058295  0.050960
#
#                                      Ton  annual_electricity_Consumption
# Price                           0.415607                        0.003394
# no_of_star                      0.059408                       -0.076051
# rating                          0.005958                       -0.058295
# discount                       -0.094042                        0.050960
# Ton                             1.000000                       -0.010936
# ...

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x="Price", y="discount", data = df, hue="annual_electricity_Consumption")
# Out:
# <Axes: xlabel='Price', ylabel='discount'>

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x="Price",y="annual_electricity_Consumption",data=df,hue="Color")
plt.show()

# %%
cross_tab = pd.crosstab(index=df['Brand'],columns=df['Color'], values=df['Price'],aggfunc="mean")
cross_tab.plot(kind='bar', stacked=True, colormap='viridis')
plt.title("Average Price by Brand and Color")
plt.xlabel("Brand")
plt.ylabel("Average Price")
plt.xticks(rotation=90) 
plt.show()

# %%
plt.figure(figsize=(8, 6))  
sns.violinplot(x=df["Price"],bins=10, color="skyblue")  

plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Density")
plt.grid()
plt.show()

# %%
sns.boxplot(x=df3,y=df.rating)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,5))

ax=df.groupby("Brand")["Price"].agg(["min","max"]).plot(kind="bar")

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=5, color='black')
plt.tight_layout()
plt.show()

# %%
df.groupby(by=["Brand"])[["Price","annual_electricity_Consumption"]].agg(["min","max"])
# Out:
#                     Price        annual_electricity_Consumption
#                       min    max                            min      max
# Brand
# Blue star           32990  49399                         577.43  1134.28
# CANDY               26990  33990                         589.14  1134.28
# CARRIER             30490  78000                         589.14  1123.77
# CRUISE              27990  27990                         686.48  1114.71
# Daikin              26900  72500                         577.43  1134.28
# Equator             26999  26999                        1114.71  1114.71
# Frigidaire          30999  30999                        1123.23  1123.23
# Godrej              26149  40800                         577.43  1134.28
# Haier               31990  68490                         577.43  1123.77
# Hisense             33000  34990                        1050.84  1134.28
# Hitachi             23236  57999                         577.43  1134.28
# ...

# %%
df.plot()
